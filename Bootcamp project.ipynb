# %%
# importing requests package
 
import requests     
 
 
def NewsFromBBC():
 
     
 
    # BBC news api
 
    # following query parameters are used
 
    # source, sortBy and apiKey
 
    query_params = {
 
      "source": "bbc-news",
 
      "sortBy": "top",
 
      "apiKey": "9fdf256654fa45159c67b7c3ca0c54e2"
 
    }
 
    main_url = " https://newsapi.org/v1/articles"
 
 
    # fetching data in json format
 
    res = requests.get(main_url, params=query_params)
 
    open_bbc_page = res.json()
 
 
    # getting all articles in a string article
 
    article = open_bbc_page["articles"]
 
 
    # empty list which will 
 
    # contain all trending news
 
    results = []
 
     
 
    for ar in article:
 
        results.append(ar["title"])
 
         
 
    for i in range(len(results)):
 
         
 
        # printing all trending news
 
        print(i + 1, results[i])
 
 
    #to read the news out loud for us
 
                  
 
# Driver Code
 
if __name__ == '__main__':
 
     
 
    # function call
 
    NewsFromBBC()
# Out:
# 1 Senate Republicans block Democrats' election bill
# 2 'Heartbreaking' conditions in US migrant child camp
# 3 US government blocks Iran-affiliated news websites
# 4 ‘Heartless’ state bars family from dying father
# 5 UN Afghan envoy Deborah Lyons alarmed at Taliban gains
# 6 What New Yorkers want from a new mayor
# 7 Turkmenistan's capital tops list of most expensive cities for expats
# 8 A fake wedding, and a $250,000 scam
# 9 Spain pardons Catalan leaders over independence bid
# 10 Angela Merkel receives Moderna as second jab after AstraZeneca shot
